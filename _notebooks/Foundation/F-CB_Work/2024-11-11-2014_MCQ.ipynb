# %% [markdown]
# ---
# toc: true
# comments: True
# layout: post
# title: CollegeBoard MCQ Review
# description: Reviewing and fixing everything I got wrong on CSA CB MCQ 1
# type: collab
# permalink: /cbwork/2014-mcq
# courses: { csa: {week: 12} }
# ---

# %% [markdown]
# <img width="1583" alt="image" src="https://github.com/user-attachments/assets/a5701b0d-ea61-44dc-a419-cb405811528d">

# %% [markdown]
# | Unit        | Q4  | Q8  | Q10  | Q12  | Q15  | Q16  | Q19  | Q21  | Q23  | Q24  | Q30  | Q31  | Q38   | Q39   | Q40   | Total  |
# | ----------- | ----| ----| -----| -----| -----| -----| -----| -----| -----| -----| -----| -----| ------| ------| ------| -------|
# | **Unit 1**  |     |     |      |      |      |      |      |      |      |      |      |      |       |       |       |   0   |
# | **Unit 2**  |     | 2.2 |      | 2.7  |      |      |      | 2.9  | 2.7  |      | 2.7  |      |       |       |       |   5   |
# | **Unit 3**  | 3.5 |     |      |      |      |      | 3.6  |      |      |      |      |      | 3.6   |       |       |   3   |
# | **Unit 4**  |     |     |      | 4.3  |      |      |      |      |      |      |      |      |       |       |       |   1   |
# | **Unit 5**  |     |     |      |      |      |      |      |      |      |      |      | 5.6  |       |       |       |   1   |
# | **Unit 6**  |     |     |      |      | 6.2  | 6.4  |      |      |      |      |      | 6.4  |       |       |       |   3   |
# | **Unit 7**  |     |     |      |      |      |      |      |      | 7.4  |      |      |      |       |       |       |   1   |
# | **Unit 8**  |     |     |      |      |      |      |      | 8.2  |      | 8.1  |      |      |       |       |       |   2   |
# | **Unit 9**  |     |     |      |      |      |      |      |      |      |      |      |      |       |       |       |   0   |
# | **Unit 10** |     |     | 10.1 |      |      |      |      |      |      |      |      |      |       | 10.1  | 10.1  |   3   |

# %% [markdown]
# # Fixing the Fun Problems
#
# <details>
# <summary><strong>Q4 (Conceptual Error)</strong></summary>
# <p>
# <img width="1048" alt="image" src="https://github.com/user-attachments/assets/6bb9b31b-1816-41e4-9f0c-59e0daf6c490">
# </p>
# <p>After division, Java automatically casts down because both variables are integers. 7/3 = 2.333 → gets cast down to 2.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q8 (Silly Mistake)</strong></summary>
# <p>
# <img width="1084" alt="image" src="https://github.com/user-attachments/assets/811e6734-ddd6-47fe-9a72-67d1f0ca1073">
# </p>
# <p>Missed that there was an empty method in the <code>Student</code> class instantiating a <code>Student()</code> object with no information.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q10 (Conceptual Error)</strong></summary>
# <p>
# <img width="1082" alt="image" src="https://github.com/user-attachments/assets/50cb650a-03f8-4545-b239-5c283151b32c">
# </p>
# <p>Guessed; didn’t realize the loop infinitely reduces the search length, causing an IndexOutOfBounds error if the element doesn’t exist.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q12 (Silly Mistake)</strong></summary>
# <p>
# <img width="1074" alt="image" src="https://github.com/user-attachments/assets/83e95f57-1a76-4c0e-9c72-8ab745420a8d">
# </p>
# <p>Overlooked that <code>k</code> starts at 1, so indices are 1, 3, 5, 7.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q15 (Conceptual Error)</strong></summary>
# <p>
# <img width="1051" alt="image" src="https://github.com/user-attachments/assets/5ca0aaf3-5f72-4cf2-bec2-3ff28c2c7665">
# </p>
# <p>Option 2 swaps indices being checked, reversing their order, which leads to incorrect comparisons.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q16 (Silly Mistake)</strong></summary>
# <p>
# <img width="1062" alt="image" src="https://github.com/user-attachments/assets/111b0671-d6aa-4936-8c9a-dd2665661896">
# </p>
# <p>Didn’t realize <code>k + a1.length - 1</code> causes repetition of the last index in <code>a1</code> because <code>k</code> starts at 0.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q19 (Conceptual Error)</strong></summary>
# <p>
# <img width="1047" alt="image" src="https://github.com/user-attachments/assets/b0cfe1de-c9fd-4070-9caa-f002f205ad7d">
# </p>
# <p>Misunderstood that <code>!()</code> encapsulating the whole statement negates it, changing AND to OR.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q21 (Silly Mistake)</strong></summary>
# <p>
# <img width="1064" alt="image" src="https://github.com/user-attachments/assets/0bc58cbb-4472-4552-a35f-f8e8fa9bacbc">
# </p>
# <p>Subtracting the number by the <code>minDiff</code> is incorrect. Not sure why I chose this answer in the first place.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q23 (Conceptual Error)</strong></summary>
# <p>
# <img width="1059" alt="image" src="https://github.com/user-attachments/assets/b415d58e-3d3a-4167-955e-97bdfe6c57a8">
# </p>
# <p>Didn’t realize iterating from right to left while adding elements to a list keeps overwriting the same position.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q24 (Conceptual Error)</strong></summary>
# <p>
# <img width="1034" alt="image" src="https://github.com/user-attachments/assets/dfc0a913-148e-4463-ad40-1a16a4b1fad6">
# </p>
# <p>Misunderstood the array’s population order: up and down, then right. The top-right <code>[0][2]</code> element is 7.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q30 (Silly Mistake)</strong></summary>
# <p>
# <img width="1042" alt="image" src="https://github.com/user-attachments/assets/d6433052-6abe-4ff5-abb0-fb94813b93ea">
# </p>
# <p>Didn’t see the “<code>howFar + 1</code>,” which makes the letter at the <code>howFar</code> index omitted since <code>.substring(x, y)</code> excludes the <code>y</code> index.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q31 (Silly Mistake)</strong></summary>
# <p>
# <img width="1049" alt="image" src="https://github.com/user-attachments/assets/df4ba8b4-1f84-4083-a252-e8ce68271fba">
# </p>
# <p>Missed the beginning of the question, which mentioned the mystery function. After seeing this, the problem made more sense.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q38 (Silly Mistake)</strong></summary>
# <p>
# <img width="1044" alt="image" src="https://github.com/user-attachments/assets/acb00b6a-6882-448b-a588-ed1c10e10639">
# </p>
# <p>The conditions should be joined by OR, and overall conditions combined with AND, due to distribution rules.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q39 (Silly Mistake)</strong></summary>
# <p>
# <img width="1035" alt="image" src="https://github.com/user-attachments/assets/c0897320-cc93-4cca-a7a9-3c8278e472d3">
# </p>
# <p>Didn’t notice two nested <code>recur()</code> calls, causing repeated steps like: 27 → 9 → 18 → 6 → 12 → 4 → 8 → 16.</p>
# </details>
#
# <hr>
#
# <details>
# <summary><strong>Q40 (Silly Mistake)</strong></summary>
# <p>
# <img width="1050" alt="image" src="https://github.com/user-attachments/assets/193d38fd-1263-447a-8850-2b69bec31e03">
# </p>
# <p>Swapped the direction in which the loop iterates. Likely a lapse in focus.</p>
# </details>
